# %%
import torch
import IPython.display as ipd

import matplotlib.pyplot as plt
import torchaudio

from cl_tts.utils.generic import load_params
from cl_tts.utils.ap import AudioProcessor

# %%
hparams_path = "../hparams/speaker_incremental/naive.yml"
params = load_params(hparams_path)["VCTK-Speaker-Inc[Tac2NV]"]["ap_params"]
ap = AudioProcessor(params)

# %%
audio_path = "../data/VCTK-mini/audios/vctk_speaker335/audio005.wav"
x = ap.load_audio(audio_path)
print(x.shape)
x = ap.trim_margin_silence(x[0], ref_level_db=22)
print(x.shape)
ipd.Audio(x, rate=params["sample_rate"])
# Out:
# torch.Size([1, 199483])
# torch.Size([140288])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
melspec = ap.melspec(x)

# %%
x_rec = ap.mel_to_wav(melspec)
ipd.Audio(x_rec, rate=params["sample_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
